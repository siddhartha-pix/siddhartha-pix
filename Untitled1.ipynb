# %%
conda install pandas
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
import pandas as pd

# %%
csvFile = pd.read_csv('india-car-dataset.csv')

# %%
csvFile
# Out:
#              OEM    MODEL  BODY TYPE  PRICE IN LAKHS  YEAR  MONTH    SALE  \
# 0         Datsun       Go  Hatchback            4.03  2020      1    88.0
# 1         Datsun  Go Plus        MUV            4.26  2020      1    55.0
# 2         Datsun   RediGo  Hatchback            3.98  2020      1  1020.0
# 3          Honda    Amaze      Sedan            6.39  2020      1  3160.0
# 4          Honda     City      Sedan           11.23  2020      1  1734.0
# ...          ...      ...        ...             ...   ...    ...     ...
# 1891  Volkswagen     Polo  Hatchback            6.49  2021     12   762.0
# 1892  Volkswagen   Taigun        SUV           11.00  2021     12  2828.0
# 1893  Volkswagen   Tiguan        SUV           11.00  2021     12    40.0
# 1894  Volkswagen    T-Roc        SUV           21.35  2021     12     NaN
# 1895  Volkswagen    Vento      Sedan           10.00  2021     12    70.0
#
#       SALE OUT OF
# 0          1163.0
# 1          1163.0
# 2          1163.0
# ...

# %%
data = pd.DataFrame(csvFile)

# %%
data
# Out:
#              OEM    MODEL  BODY TYPE  PRICE IN LAKHS  YEAR  MONTH    SALE  \
# 0         Datsun       Go  Hatchback            4.03  2020      1    88.0
# 1         Datsun  Go Plus        MUV            4.26  2020      1    55.0
# 2         Datsun   RediGo  Hatchback            3.98  2020      1  1020.0
# 3          Honda    Amaze      Sedan            6.39  2020      1  3160.0
# 4          Honda     City      Sedan           11.23  2020      1  1734.0
# ...          ...      ...        ...             ...   ...    ...     ...
# 1891  Volkswagen     Polo  Hatchback            6.49  2021     12   762.0
# 1892  Volkswagen   Taigun        SUV           11.00  2021     12  2828.0
# 1893  Volkswagen   Tiguan        SUV           11.00  2021     12    40.0
# 1894  Volkswagen    T-Roc        SUV           21.35  2021     12     NaN
# 1895  Volkswagen    Vento      Sedan           10.00  2021     12    70.0
#
#       SALE OUT OF
# 0          1163.0
# 1          1163.0
# 2          1163.0
# ...

# %%
print(df.iloc[1600:1650])
# Out:
#                 OEM          MODEL  BODY TYPE  PRICE IN LAKHS  YEAR  MONTH  \
# 1600       Mahindra         XUV700        SUV           12.96  2021      9
# 1601  Maruti Suzuki           Alto  Hatchback            3.25  2021      9
# 1602  Maruti Suzuki         Baleno  Hatchback            6.03  2021      9
# 1603  Maruti Suzuki        Celerio  Hatchback            5.14  2021      9
# 1604  Maruti Suzuki           Ciaz      Sedan            8.67  2021      9
# 1605  Maruti Suzuki          Dzire      Sedan            6.09  2021      9
# 1606  Maruti Suzuki           Eeco        Van            4.53  2021      9
# 1607  Maruti Suzuki         Ertiga        MUV            8.11  2021      9
# 1608  Maruti Suzuki          Ignis  Hatchback            5.08  2021      9
# 1609  Maruti Suzuki        S-Cross        SUV            8.60  2021      9
# 1610  Maruti Suzuki       S-Presso        SUV            3.85  2021      9
# ...

# %%
df = pd.DataFrame(data)

nan_values = df.isna().any()

print (nan_values)
# Out:
# OEM               False
# MODEL             False
# BODY TYPE         False
# PRICE IN LAKHS    False
# YEAR              False
# MONTH             False
# SALE               True
# SALE OUT OF        True
# dtype: bool

# %%
df.dropna() #will NOT return a new DataFrame, but it will remove all rows containg NULL values from the original DataFrame.
# Out:
#              OEM     MODEL  BODY TYPE  PRICE IN LAKHS  YEAR  MONTH    SALE  \
# 0         Datsun        Go  Hatchback            4.03  2020      1    88.0
# 1         Datsun   Go Plus        MUV            4.26  2020      1    55.0
# 2         Datsun    RediGo  Hatchback            3.98  2020      1  1020.0
# 3          Honda     Amaze      Sedan            6.39  2020      1  3160.0
# 4          Honda      City      Sedan           11.23  2020      1  1734.0
# ...          ...       ...        ...             ...   ...    ...     ...
# 1889      Toyota  Vellfire        Van           89.85  2021     12    23.0
# 1891  Volkswagen      Polo  Hatchback            6.49  2021     12   762.0
# 1892  Volkswagen    Taigun        SUV           11.00  2021     12  2828.0
# 1893  Volkswagen    Tiguan        SUV           11.00  2021     12    40.0
# 1895  Volkswagen     Vento      Sedan           10.00  2021     12    70.0
#
#       SALE OUT OF
# 0          1163.0
# 1          1163.0
# ...

# %%
df['SALE'].isna().sum()
# Out:
# 284

# %%
dd

# %%
df['SALE OUT OF'].isna().sum()
# Out:
# 75

# %%
x = df['SALE'].mean()
x
# Out:
# 3363.013027295285

# %%
y = df["SALE"].median()
y
# Out:
# 1632.0

# %%
z = df["SALE"].mode()[0]
z
# Out:
# 1.0

# %%
K = df["SALE OUT OF"].mode()[0]
K
# Out:
# 13702.0

# %%
L = df["SALE OUT OF"].median()
L
# Out:
# 13002.0

# %%
M = df["SALE OUT OF"].mean()
M
# Out:
# 31949.90170236134

# %%
df['SALE'].fillna(100,inplace = True)

# %%
df['SALE OUT OF'].fillna(L,inplace = True)

# %%
pip install mysql-connector-python
# Out:
# ...
#
# ...

# %%
import mysql.connector as msql
from mysql.connector import Error
try:
    conn = msql.connect(host='localhost', user='root',  
                        password='3793')#give ur username, password
    if conn.is_connected():
        mycursor = conn.cursor()
        mycursor.execute("CREATE DATABASE car_db")
        print("Database is created")
except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# Database is created

# %%
import mysql.connector as msql
from mysql.connector import Error
try:
    conn = msql.connect(host='localhost', database='car_db', user='root', password='3793')
    if conn.is_connected():
        mycursor = conn.cursor()
        query =("create table cardata(company Varchar(100), model varchar(100), bodytype varchar(100), priceinlakh float, year int, month int, sales int, salesout int)")
        mycursor.execute(query)
except Error as e:
    print("Error while connecting to MySQL", e)

# %%
try:
    conn = msql.connect(host='localhost', database='car_db', user='root', password='3793')
    if conn.is_connected():
        mycursor = conn.cursor()
        for i,row in data.iterrows():
            #here %S means string values 
            sql = "INSERT INTO cardata VALUES (%s,%s,%s,%s,%s,%s,%s,%s)"
            mycursor.execute(sql, tuple(row))
            print("Record inserted")
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...
